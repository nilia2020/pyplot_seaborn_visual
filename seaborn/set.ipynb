# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x=['A', 'B', 'C'], y=[1, 2, 3], hue=['A', 'B', 'C'], width=0.5)
# %matplotlib inline

# %%
sns.set_theme(style="whitegrid", palette="pastel", font_scale=1.1)
sns.barplot(x=['A', 'B', 'C'], y=[1, 2, 3], hue=['A', 'B', 'C'], width=0.5)
# %matplotlib inline
